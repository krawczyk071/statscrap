# %%
https://understat.readthedocs.io/en/latest/classes/understat.html#the-functions

# %%
import asyncio
import json

import aiohttp

from understat import Understat


async def main():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        data = await understat.get_league_players("epl", 2018, {"team_title": "Manchester United"})
        print(json.dumps(data))


if __name__ == "__main__":
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    loop.run_until_complete(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\krawc\OneDrive\Documents\code\pythons\statscrap\test.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/statscrap/test.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> loop = asyncio.new_event_loop()
#      <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/statscrap/test.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a> asyncio.set_event_loop(loop)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/krawc/OneDrive/Documents/code/pythons/statscrap/test.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a> loop.run_until_complete(main())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:626, in BaseEventLoop.run_until_complete(self, future)
#     615 """Run until the Future is done.
#     616
# ...

# %%
json_dict=[{"id": "1740", "player_name": "Paul Pogba", "games": "35", "time": "3013", "goals": "13", "xG": "15.877537530846894", "assists": "9", "xA": "5.186745874583721", "shots": "105", "key_passes": "55", "yellow_cards": "6", "red_cards": "0", "position": "M S", "team_title": "Manchester United", "npg": "6", "npxG": "8.265851297415793", "xGChain": "21.125928223133087", "xGBuildup": "11.593517602421343"}, {"id": "594", "player_name": "Romelu Lukaku", "games": "32", "time": "2113", "goals": "12", "xG": "13.105172824114561", "assists": "0", "xA": "2.3202134016901255", "shots": "55", "key_passes": "21", "yellow_cards": "4", "red_cards": "0", "position": "F S", "team_title": "Manchester United", "npg": "12", "npxG": "13.105172824114561", "xGChain": "15.425698295235634", "xGBuildup": "5.4260068498551846"}, {"id": "553", "player_name": "Anthony Martial", "games": "27", "time": "1632", "goals": "10", "xG": "7.954480409622192", "assists": "2", "xA": "3.2472198167815804", "shots": "39", "key_passes": "36", "yellow_cards": "2", "red_cards": "0", "position": "F M S", "team_title": "Manchester United", "npg": "9", "npxG": "7.193311810493469", "xGChain": "11.796286111697555", "xGBuildup": "3.6007302813231945"}, {"id": "556", "player_name": "Marcus Rashford", "games": "33", "time": "2360", "goals": "10", "xG": "11.614460183307528", "assists": "6", "xA": "5.270444078370929", "shots": "84", "key_passes": "38", "yellow_cards": "3", "red_cards": "1", "position": "F M S", "team_title": "Manchester United", "npg": "10", "npxG": "11.614460183307528", 
"xGChain": "16.822122670244426", "xGBuildup": "5.243193206842989"}, {"id": "558", "player_name": "Jesse Lingard", "games": "27", 
"time": "1677", "goals": "4", "xG": "4.844163816422224", "assists": "2", "xA": "3.156425293069333", "shots": "32", "key_passes": 
"17", "yellow_cards": "3", "red_cards": "0", "position": "F M S", "team_title": "Manchester United", "npg": "3", "npxG": "4.082991819828749", "xGChain": "10.800292232539505", "xGBuildup": "5.214572378434241"}, {"id": "554", "player_name": "Juan Mata", "games": "22", "time": "1306", "goals": "3", "xG": "1.5762369083240628", "assists": "2", "xA": "3.700430253520608", "shots": "19", "key_passes": "30", "yellow_cards": "3", "red_cards": "0", "position": "F M S", "team_title": "Manchester United", "npg": "3", "npxG": "1.5762369083240628", "xGChain": "5.144090541638434", "xGBuildup": "2.1955521078780293"}, {"id": "552", "player_name": "Ander Herrera", "games": "22", "time": "1404", "goals": "2", "xG": "1.511772520840168", "assists": "3", "xA": "2.056090025231242", "shots": "21", "key_passes": "15", "yellow_cards": "4", "red_cards": "0", "position": "D M S", "team_title": "Manchester United", "npg": "2", "npxG": "1.511772520840168", "xGChain": "10.2428825404495", "xGBuildup": "8.346531592309475"}, {"id": "631", "player_name": "Ashley Young", "games": "30", "time": "2565", "goals": "2", "xG": "0.49426380172371864", "assists": "2", "xA": "3.9991636965423822", "shots": "12", "key_passes": "39", "yellow_cards": "8", "red_cards": "1", "position": "D S", "team_title": "Manchester United", "npg": "2", "npxG": "0.49426380172371864", "xGChain": "10.53615704504773", "xGBuildup": "8.199239152949303"}, {"id": "5560", "player_name": "Scott McTominay", "games": "16", "time": "852", "goals": "2", "xG": "1.588795562274754", "assists": "0", "xA": "0.017006199806928635", "shots": "15", "key_passes": "1", "yellow_cards": "1", "red_cards": "0", "position": "D M S", "team_title": "Manchester United", "npg": "2", "npxG": "1.588795562274754", "xGChain": "3.5094783529639244", "xGBuildup": "2.3852984234690666"}, {"id": "498", "player_name": "Alexis S\u00e1nchez", "games": "20", "time": "875", "goals": "1", "xG": "1.7134784050285816", "assists": "3", "xA": "3.546852245926857", "shots": "17", "key_passes": "21", "yellow_cards": "3", "red_cards": "0", "position": "F M S", "team_title": "Manchester United", "npg": "1", "npxG": "1.7134784050285816", "xGChain": "6.49897401034832", "xGBuildup": "2.985114647075534"}, {"id": "628", "player_name": "Chris Smalling", "games": "24", "time": "2130", "goals": "1", "xG": "1.114168887026608", "assists": "0", "xA": "0.12397489696741104", "shots": "11", "key_passes": "2", "yellow_cards": "1", "red_cards": "0", "position": "D", "team_title": "Manchester United", "npg": "1", "npxG": "1.114168887026608", "xGChain": "3.7084142826497555", 
"xGBuildup": "3.7084142826497555"}, {"id": "697", "player_name": "Nemanja Matic", "games": "28", "time": "2450", "goals": "1", "xG": "1.7107221204787493", "assists": "0", "xA": "0.5648093018680811", "shots": "12", "key_passes": "13", "yellow_cards": "6", "red_cards": "1", "position": "D M", "team_title": "Manchester United", "npg": "1", "npxG": "1.7107221204787493", "xGChain": "11.787703746929765", "xGBuildup": "11.243930291384459"}, {"id": "922", "player_name": "Andreas Pereira", "games": "15", "time": "593", 
"goals": "1", "xG": "0.26869879849255085", "assists": "1", "xA": "0.8848193176090717", "shots": "8", "key_passes": "9", "yellow_cards": "5", "red_cards": "0", "position": "M S", "team_title": "Manchester United", "npg": "1", "npxG": "0.26869879849255085", "xGChain": "3.2008728506043553", "xGBuildup": "2.4986268701031804"}, {"id": "1006", "player_name": "Luke Shaw", "games": "29", "time": "2594", "goals": "1", "xG": "1.533868563361466", "assists": "4", "xA": "4.323225478641689", "shots": "21", "key_passes": "33", "yellow_cards": "11", "red_cards": "0", "position": "D", "team_title": "Manchester United", "npg": "1", "npxG": "1.533868563361466", "xGChain": "14.971799179911613", "xGBuildup": "12.218418538570404"}, {"id": "6080", "player_name": "Victor Lindel\u00f6f", 
"games": "30", "time": "2604", "goals": "1", "xG": "0.8407717123627663", "assists": "1", "xA": "1.583196997642517", "shots": "8", "key_passes": "5", "yellow_cards": "1", "red_cards": "0", "position": "D S", "team_title": "Manchester United", "npg": "1", "npxG": "0.8407717123627663", "xGChain": "8.736518723890185", "xGBuildup": "7.977655736729503"}, {"id": "6817", "player_name": "Fred", "games": "17", "time": "1045", "goals": "1", "xG": "0.904592817183584", "assists": "1", "xA": "0.9538170415908098", "shots": "17", "key_passes": "12", "yellow_cards": "2", "red_cards": "0", "position": "M S", "team_title": "Manchester United", "npg": "1", 
"npxG": "0.904592817183584", "xGChain": "7.189614565111697", "xGBuildup": "5.615092068910599"}, {"id": "546", "player_name": "David de Gea", "games": "38", "time": "3420", "goals": "0", "xG": "0", "assists": "0", "xA": "0", "shots": "0", "key_passes": "0", "yellow_cards": "1", "red_cards": "0", "position": "GK", "team_title": "Manchester United", "npg": "0", "npxG": "0", "xGChain": "3.3250256115570664", "xGBuildup": "3.3250256115570664"}, {"id": "550", "player_name": "Marcos Rojo", "games": "5", "time": "208", 
"goals": "0", "xG": "0.23537209257483482", "assists": "0", "xA": "0", "shots": "6", "key_passes": "0", "yellow_cards": "2", "red_cards": "0", "position": "D S", "team_title": "Manchester United", "npg": "0", "npxG": "0.23537209257483482", "xGChain": "0.7415014170110226", "xGBuildup": "0.7083711177110672"}, {"id": "557", "player_name": "Matteo Darmian", "games": "6", "time": "447", "goals": "0", "xG": "0.028308799490332603", "assists": "0", "xA": "0.050413601100444794", "shots": "1", "key_passes": "2", "yellow_cards": "0", "red_cards": "0", "position": "D M S", "team_title": "Manchester United", "npg": "0", "npxG": "0.028308799490332603", "xGChain": "0.5790707990527153", "xGBuildup": "0.5339906997978687"}, {"id": "627", "player_name": "Antonio Valencia", "games": "6", "time": "465", "goals": "0", "xG": "0.03736419975757599", "assists": "0", "xA": "0.5265980958938599", "shots": "2", "key_passes": "7", "yellow_cards": "2", "red_cards": "0", "position": "D S", "team_title": "Manchester United", "npg": "0", "npxG": "0.03736419975757599", "xGChain": "1.7253731787204742", "xGBuildup": "1.3759241849184036"}, {"id": "630", "player_name": "Marouane Fellaini", "games": "14", "time": "728", "goals": "0", "xG": "0.7338949963450432", "assists": "1", "xA": "0.20478229597210884", "shots": "7", "key_passes": "3", "yellow_cards": "1", "red_cards": "0", "position": "M S", "team_title": "Manchester United", "npg": "0", "npxG": "0.7338949963450432", "xGChain": "1.9953790679574013", "xGBuildup": "1.2806162796914577"}, {"id": "951", "player_name": "Phil Jones", "games": "18", "time": "1266", "goals": "0", "xG": "0.5517958011478186", "assists": "1", "xA": "0.8154120333492756", "shots": "5", "key_passes": "3", "yellow_cards": "1", "red_cards": "0", "position": "D S", "team_title": "Manchester United", "npg": "0", "npxG": "0.5517958011478186", "xGChain": "3.823229741305113", "xGBuildup": "3.5550857298076153"}, {"id": "1739", "player_name": "Eric Bailly", "games": "12", "time": "639", "goals": "0", "xG": "0.24984100461006165", "assists": "0", "xA": "0", "shots": "3", "key_passes": "0", "yellow_cards": "0", "red_cards": "1", "position": "D S", "team_title": "Manchester United", "npg": "0", "npxG": "0.24984100461006165", "xGChain": "2.9941667332313955", "xGBuildup": "2.9941667332313955"}, {"id": "5598", "player_name": "Angel Gomes", "games": "2", "time": "23", "goals": "0", "xG": "0.10693320259451866", "assists": "0", "xA": "0", "shots": "2", "key_passes": "0", "yellow_cards": "0", "red_cards": "0", "position": "S", "team_title": "Manchester United", "npg": "0", 
"npxG": "0.10693320259451866", "xGChain": "0.2809922993183136", "xGBuildup": "0.17405900359153748"}, {"id": "7281", "player_name": "Diogo Dalot", "games": "16", "time": "1015", "goals": "0", "xG": "0.7152223102748394", "assists": "2", "xA": "2.7341757230460644", "shots": "15", "key_passes": "17", "yellow_cards": "3", "red_cards": "0", "position": "D F M S", "team_title": "Manchester United", "npg": "0", "npxG": "0.7152223102748394", "xGChain": "4.4227335145697", "xGBuildup": "2.3708081021904945"}, {"id": "7438", "player_name": "James Garner", "games": "1", "time": "1", "goals": "0", "xG": "0", "assists": "0", "xA": "0", "shots": "0", "key_passes": "0", "yellow_cards": "0", "red_cards": "0", "position": "S", "team_title": "Manchester United", "npg": "0", "npxG": "0", "xGChain": "0", "xGBuildup": "0"}, {"id": "7439", "player_name": "Tahith Chong", "games": "2", "time": "35", "goals": "0", "xG": "0.2937690019607544", "assists": "0", "xA": "0", "shots": "2", "key_passes": "0", "yellow_cards": "0", "red_cards": "0", "position": "S", "team_title": "Manchester United", "npg": "0", "npxG": "0.2937690019607544", "xGChain": "0.4904190003871918", "xGBuildup": "0.1966490000486374"}, {"id": "7490", "player_name": "Mason Greenwood", "games": "3", "time": "111", "goals": "0", "xG": "0.7973629832267761", "assists": "0", "xA": "0.07234489917755127", "shots": "7", "key_passes": "3", "yellow_cards": "0", "red_cards": "0", "position": "F S", "team_title": "Manchester United", "npg": "0", "npxG": "0.7973629832267761", "xGChain": "1.0192560255527496", "xGBuildup": "0.6869980096817017"}]

# %%
import pandas as pd
import json

file_path = 'out1'
# out_dict = json.loads(json_string)
# df = pd.DataFrame.from_dict(out_dict)
# df.to_csv(file_path,index=False)

# %%
pd.DataFrame.from_dict(json_dict)
# Out:
#       id        player_name games  time goals                    xG assists  \
# 0   1740         Paul Pogba    35  3013    13    15.877537530846894       9
# 1    594      Romelu Lukaku    32  2113    12    13.105172824114561       0
# 2    553    Anthony Martial    27  1632    10     7.954480409622192       2
# 3    556    Marcus Rashford    33  2360    10    11.614460183307528       6
# 4    558      Jesse Lingard    27  1677     4     4.844163816422224       2
# 5    554          Juan Mata    22  1306     3    1.5762369083240628       2
# 6    552      Ander Herrera    22  1404     2     1.511772520840168       3
# 7    631       Ashley Young    30  2565     2   0.49426380172371864       2
# 8   5560    Scott McTominay    16   852     2     1.588795562274754       0
# 9    498     Alexis Sánchez    20   875     1    1.7134784050285816       3
# 10   628     Chris Smalling    24  2130     1     1.114168887026608       0
# ...
